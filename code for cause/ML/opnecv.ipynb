# %%
from PIL import Image
import numpy as np 
import matplotlib.pyplot as plt    
# %matplotlib inline

import cv2

# %%
img = Image.open("/home/achintya/Downloads/Rodeoalbum.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x219 at 0x7FF40C4B4CD0>

# %%
arr = np.array(img)

# %%
frame = cv2.imread("/home/achintya/Downloads/Rodeoalbum.jpg")

# %%
plt.imshow(frame)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x219 at 0x7FF40C4B4CD0>

# %%
rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# %%
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(rgb)

# %%
classifier = cv2.CascadeClassifier("/home/achintya/Downloads/haarcascade_frontalface_default.xml")

# %%
faces = classifier.detectMultiScale(frame)

# %%
for x, y, w, h in faces:    
   out = cv2.rectangle(frame, (x,y), (x+w), (y+h),(0,255,0), 3)

# %%
cv2.imshow('frame', frame)
