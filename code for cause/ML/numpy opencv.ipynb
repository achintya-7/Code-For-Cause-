# %%
from PIL import Image
import numpy as np 
import matplotlib.pyplot as plt    
# %matplotlib inline

# %%
img = Image.open("/home/achintya/Downloads/dm5.jpg")

# %%
arr = np.array(img)

# %%
arr.shape
# Out:
# (720, 1280, 3)

# %%
red = arr[:, :, 0]

# %%
plt.imshow(arr)

# %%
work = arr.copy()

# %%
work[:, :, [1, 2]] = 0 # 0 is Red, 1 is Green, 2 is Blue, it cobverts all the values to 0 only represt RED

# %%
work.shape
# Out:
# (720, 1280, 3)

# %%
plt.imshow(work)

# %%
gray = arr.mean(axis=2)

# %%
plt.imshow(gray)

# %%
plt.imshow(gray, cmap="gray")
